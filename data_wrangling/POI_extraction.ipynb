# %%
import pandas as pd

# %%
gardens_reserves_df = pd.read_csv("gardens & reserves.csv")

# %%
hospitals_df = pd.read_csv("Hospital_Locations.csv")

# %%
sport_recreation_df = pd.read_csv("SportandRec.csv", )

# %%
vpa_open_space_df = pd.read_csv("VPA_Open_Space.csv")

# %%
col_names_gandr = gardens_reserves_df.columns
col_names_hospt = hospitals_df.columns
col_names_sandr = sport_recreation_df.columns
col_names_vpa = vpa_open_space_df.columns

# %%
print("Gardens & reservers columns:", col_names_gandr)
print("Hospitals columns:", col_names_hospt)
print("Sports and recreational:", col_names_sandr)
print("VPA open spaces:", col_names_vpa)
# Out:
# Gardens & reservers columns: Index(['Name', 'Address', 'Suburb', 'Postcode', 'State', 'Business Category',
#        'LGA', 'Region'],
#       dtype='object')
# Hospitals columns: Index(['X', 'Y', 'FID', 'LabelName', 'OpsName', 'Type', 'StreetNum',
#        'RoadName', 'RoadType', 'RoadSuffix', 'CampusCode', 'LGAName',
#        'LocalityNa', 'Postcode', 'VicgovRegi', 'State', 'ServiceNam'],
#       dtype='object')
# Sports and recreational: Index(['X', 'Y', 'OBJECTID', 'Facility_ID', 'FacilityName', 'StreetNo',
#        'StreetName', 'StreetType', 'SuburbTown', 'Postcode', 'Latitude',
#        'Longitude', 'FaciltySportPlayedID', 'SportsPlayed',
#        'NumberFieldCourts', 'FieldSurfaceType', 'FacilityAge',
#        'FacilityCondition', 'FacilityUpgradeAge', 'Changerooms', 'LGA'],
#       dtype='object')
# VPA open spaces: Index(['FID', 'LGA', 'VM_PARCEL_', 'VM_PARCE_1', 'DATA_SOURC', 'OS_CATEGOR',
#        'OS_CATEG_2', 'OWNER_TYPE', 'PARK_NAME', 'OS_STATUS', 'OS_ACCESS',
# ...

# %%
hospitals_df.LGAName.value_counts()
# Out:
# MELBOURNE               16
# GLEN EIRA               12
# STONNINGTON             11
# MONASH                  11
# BOROONDARA              10
# Melbourne (C)            9
# CASEY                    8
# GREATER DANDENONG        8
# WHITEHORSE               7
# GREATER GEELONG          6
# BRIMBANK                 6
# FRANKSTON                6
# Buloke (S)               5
# BANYULE                  5
# BAYSIDE                  5
# DAREBIN                  5
# Campaspe (S)             4
# MORELAND                 4
# KINGSTON                 4
# PORT PHILLIP             4
# Maribyrnong (C)          4
# MORNINGTON PENINSULA     4
# MARIBYRNONG              4
# Boroondara (C)           4
# Corangamite (S)          4
# Moira (S)                4
# MAROONDAH                4
# Hindmarsh (S)            4
# YARRA                    4
# BALLARAT                 3
#                         ..
# GREATER SHEPPARTON       1
# Indigo (S)               1
# Latrobe (C)              1
# ...

# %%
if hospitals_df['LGAName'].str.contains('glen').any():
    print ("glen is there")

# %%
hospitals_df['LGAName'].str.contains('Glen').any()
# Out:
# True

# %%
hospitals_df['LGAName'].str.contains('GLEN').any()
# Out:
# True

# %%
hospitals_df.head(6)
# Out:
#             X          Y  FID                                    LabelName  \
# 0  144.983399 -37.809681    1       East Melbourne Specialist Day Hospital
# 1  145.149300 -37.951400    2                   Windsor Avenue Day Surgery
# 2  145.344653 -38.034580    3       Hyperbaric Health Wound Centre Berwick
# 3  143.832286 -37.540553    4                Ballarat Day Procedure Centre
# 4  145.143379 -38.148189    5  Bayside Day Procedure and Specialist Centre
# 5  144.261500 -36.761900    6                          Bendigo Day Surgery
#
#                          OpsName     Type  StreetNum    RoadName RoadType  \
# 0    EAST MELBOURNE DAY HOSPITAL  PRIVATE         23   CLARENDON   STREET
# 1     WINDSOR AVENUE DAY SURGERY  PRIVATE         17     WINDSOR   AVENUE
# 2    HYPERBARIC HEALTH - BERWICK  PRIVATE          3        GIBB   STREET
# 3  BALLARAT DAY PROCEDURE CENTRE  PRIVATE  1117-1123      HOWITT   STREET
# ...

# %%
hospital_df_required = hospitals_df[['X','Y','OpsName','StreetNum','RoadName','RoadType',"LGAName",'Postcode']]

# %%
hospital_df_required['address'] = hospital_df_required['StreetNum'] +' ' +hospital_df_required['RoadName']+' '+hospital_df_required['RoadType']
# Out:
# /Users/srikarmanthatti/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
hospital_df_required['category'] = 'Hospital'
# Out:
# /Users/srikarmanthatti/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
hospital_df_required.columns = ['longitude', 'latitude', 'name', 'council', 'postcode', 'address', 'category']

# %%
hospital_df_required.head(3)
# Out:
#     longitude   latitude                         name            council  \
# 0  144.983399 -37.809681  EAST MELBOURNE DAY HOSPITAL          MELBOURNE
# 1  145.149300 -37.951400   WINDSOR AVENUE DAY SURGERY  GREATER DANDENONG
# 2  145.344653 -38.034580  HYPERBARIC HEALTH - BERWICK              CASEY
#
#    postcode              address  category
# 0      3002  23 CLARENDON STREET  Hospital
# 1      3171    17 WINDSOR AVENUE  Hospital
# 2      3806        3 GIBB STREET  Hospital

# %%
sport_recreation_df.head(5)
# Out:
#             X          Y  OBJECTID  Facility_ID  \
# 0  144.640316 -37.898601      9001   WYNDHA8530
# 1  144.727500 -37.872000      9002  WYNDHA11288
# 2  144.659074 -37.913492      9003   WYNDHA8521
# 3  144.674980 -37.924111      9004   WYNDHA8516
# 4  144.717830 -37.840037      9005   WYNDHA5496
#
#                        FacilityName StreetNo StreetName StreetType  \
# 0  Werribee Sports & Fitness Centre      NaN     Ballan       Road
# 1             Hoppers Indoor Sportz      NaN     Graham      Court
# 2           Riverside Indoor Sports       13  Riverside     Avenue
# 3        National Equestrian Centre      NaN          K       Road
# 4           Clearwood Drive Reserve      NaN  Clearwood      Drive
#
#          SuburbTown  Postcode  ...   Longitude  FaciltySportPlayedID  \
# 0          WERRIBEE    3030.0  ...  144.640316                 26686
# 1  HOPPERS CROSSING    3029.0  ...  144.727500                 26982
# ...

# %%
sport_recreation_df_required = sport_recreation_df[['X', 'Y','FacilityName','LGA','Postcode','StreetNo',
       'StreetName', 'StreetType', 'SuburbTown']]

# %%
sport_recreation_df_required['SuburbTown'] = sport_recreation_df_required.SuburbTown.str.title()
# Out:
# /Users/srikarmanthatti/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
sport_recreation_df_required['address'] = sport_recreation_df_required['StreetName'] +' '+sport_recreation_df_required['StreetType']+' '+sport_recreation_df_required['SuburbTown']
# Out:
# /Users/srikarmanthatti/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
del sport_recreation_df_required['StreetName']
del sport_recreation_df_required['StreetNo']
del sport_recreation_df_required['StreetType']
del sport_recreation_df_required['SuburbTown']

# %%
sport_recreation_df_required['category'] = 'Sport and Recreation'
# Out:
# /Users/srikarmanthatti/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
sport_recreation_df_required.columns = ['longitude', 'latitude', 'name', 'council', 'postcode', 'address', 'category']

# %%
sport_recreation_df_required['council'] = sport_recreation_df_required.council.str.title()
# Out:
# /Users/srikarmanthatti/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
sport_recreation_df_required['postcode'] = sport_recreation_df_required['postcode'].astype(str)
# Out:
# /Users/srikarmanthatti/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
type(sport_recreation_df_required['postcode'][1])
# Out:
# str

# %%
vpa_open_space_df.head(5)
# Out:
#    FID         LGA  VM_PARCEL_ VM_PARCE_1               DATA_SOURC  \
# 0    1  BOROONDARA   3\LP28215      95086  VM Features of Interest
# 1    2  BOROONDARA  159\LP5481  203973157               VM Parcels
# 2    3  BOROONDARA   3\TP84208  203973089               VM Parcels
# 3    4  BOROONDARA   1\TP84208  203973073               VM Parcels
# 4    5  BOROONDARA  1\TP802753  203972979               VM Parcels
#
#               OS_CATEGOR      OS_CATEG_2        OWNER_TYPE  \
# 0  Tertiary institutions  Not applicable  State Government
# 1      Parks and gardens  Not applicable  Local government
# 2      Parks and gardens  Not applicable  Local government
# 3      Parks and gardens  Not applicable  Local government
# 4      Parks and gardens  Not applicable  Local government
#
#                                            PARK_NAME OS_STATUS  ...      HA  \
# 0  Swinburne University Of Technology & Tafe Divi...  Existing  ...  0.0166
# ...

# %%
glen_eira_df_poi = pd.read_csv("glen_eira_poi_stella.csv")

# %%
sport_recreation_df_required,
hospital_df_required
# Out:
#       longitude   latitude                            name  \
# 0    144.983399 -37.809681     EAST MELBOURNE DAY HOSPITAL
# 1    145.149300 -37.951400      WINDSOR AVENUE DAY SURGERY
# 2    145.344653 -38.034580     HYPERBARIC HEALTH - BERWICK
# 3    143.832286 -37.540553   BALLARAT DAY PROCEDURE CENTRE
# 4    145.143379 -38.148189    BAYSIDE DAY PROCEDURE CENTRE
# 5    144.261500 -36.761900             BENDIGO DAY SURGERY
# 6    145.041233 -37.920125         SURGICENTRE - BENTLEIGH
# 7    145.346519 -38.033496    SURGICENTRE AND EYE -BERWICK
# 8    144.991817 -37.912560        BRIGHTON PLASTIC SURGERY
# 9    145.061879 -37.692573       BUNDOORA ENDOSCOPY CENTRE
# 10   145.056802 -37.960467       CHESTERVILLE DAY HOSPITAL
# 11   144.964771 -37.745017         COBURG ENDOSCOPY CENTRE
# 12   145.223301 -37.974247    DANDENONG DAY SURGERY CENTRE
# 13   145.017576 -37.781101      DAREBIN ENDOSCOPY SERVICES
# 14   145.107588 -37.705329       DIAVERUM - DIAMOND VALLEY
# ...

# %%
print("shape of hospital df is :", len(hospital_df_required))
print("shape of sport_recreation_df_required df is :", len(sport_recreation_df_required))
print("shape of glen_eira_df_poi df is :", len(glen_eira_df_poi))
# Out:
# shape of hospital df is : 325
# shape of sport_recreation_df_required df is : 9471
# shape of glen_eira_df_poi df is : 1788

# %%
del main_df

# %%
main_df = pd.concat([hospital_df_required,sport_recreation_df_required,glen_eira_df_poi])
# Out:
# /Users/srikarmanthatti/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
print("columns of hospital_df: ", hospital_df_required.columns)
print("columns of sport_recreation_df_required: ", sport_recreation_df_required.columns)
print("columns of glen_eira_df_poi: ", glen_eira_df_poi.columns)
# Out:
# columns of hospital_df:  Index(['longitude', 'latitude', 'name', 'council', 'postcode', 'address',
#        'category'],
#       dtype='object')
# columns of sport_recreation_df_required:  Index(['longitude', 'latitude', 'name', 'council', 'postcode', 'address',
#        'category'],
#       dtype='object')
# columns of glen_eira_df_poi:  Index(['Unnamed: 0', 'longitude', 'latitude', 'name', 'council', 'postcode',
#        'address', 'category'],
#       dtype='object')

# %%
sport_recreation_df_required.head(3)
# Out:
#     longitude   latitude                              name  council postcode  \
# 0  144.640316 -37.898601  Werribee Sports & Fitness Centre  Wyndham   3030.0
# 1  144.727500 -37.872000             Hoppers Indoor Sportz  Wyndham   3029.0
# 2  144.659074 -37.913492           Riverside Indoor Sports  Wyndham   3030.0
#
#                          address              category
# 0           Ballan Road Werribee  Sport and Recreation
# 1  Graham Court Hoppers Crossing  Sport and Recreation
# 2      Riverside Avenue Werribee  Sport and Recreation

# %%
hospital_df_required.head(3)
# Out:
#     longitude   latitude                         name            council  \
# 0  144.983399 -37.809681  EAST MELBOURNE DAY HOSPITAL          MELBOURNE
# 1  145.149300 -37.951400   WINDSOR AVENUE DAY SURGERY  GREATER DANDENONG
# 2  145.344653 -38.034580  HYPERBARIC HEALTH - BERWICK              CASEY
#
#    postcode              address  category
# 0      3002  23 CLARENDON STREET  Hospital
# 1      3171    17 WINDSOR AVENUE  Hospital
# 2      3806        3 GIBB STREET  Hospital

# %%
final_glen_df = pd.read_csv("Final_draft_glen_eira.csv")

# %%
final_glen_df.postcode.value_counts()
# Out:
# 3165    89
# 3204    80
# 3183    62
# 3185    50
# 3162    43
# 3163    39
# Name: postcode, dtype: int64

# %%
del final_glen_df['geom']

# %%
main_df = pd.concat([hospital_df_required,sport_recreation_df_required,final_glen_df])

# %%
main_df.head(3)
# Out:
#     longitude   latitude                         name            council  \
# 0  144.983399 -37.809681  East Melbourne Day Hospital          Melbourne
# 1  145.149300 -37.951400   Windsor Avenue Day Surgery  Greater Dandenong
# 2  145.344653 -38.034580  Hyperbaric Health - Berwick              Casey
#
#   postcode              address  category
# 0     3002  23 Clarendon Street  Hospital
# 1     3171    17 Windsor Avenue  Hospital
# 2     3806        3 Gibb Street  Hospital

# %%
main_df['name'] = main_df.name.str.title()

# %%
main_df[main_df['postcode'] == '3165.0']
# Out:
#        longitude   latitude                                     name  \
# 903   145.068459 -37.926021                           Centenary Park
# 907   145.059689 -37.929295             King George Vi Memorial Park
# 909   145.076431 -37.917615                      Mackie Road Reserve
# 911   145.072359 -37.934102              Moorleigh Community Village
# 915   145.061671 -37.916884      Glen Eira Sports And Aquatic Centre
# 918   145.061671 -37.916884      Glen Eira Sports And Aquatic Centre
# 921   145.061671 -37.916884                           Bailey Reserve
# 924   145.068459 -37.926021                           Centenary Park
# 925   145.068459 -37.926021                           Centenary Park
# 930   145.059689 -37.929295             King George Vi Memorial Park
# 934   145.076431 -37.917615                      Mackie Road Reserve
# 937   145.072359 -37.934102              Moorleigh Community Village
# 938   145.072359 -37.934102              Moorleigh Community Village
# ...

# %%
main_df['postcode'] = pd.to_numeric(main_df['postcode'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "nan"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-173-d31b0691bcac> in <module>()
# ----> 1 main_df['postcode'] = pd.to_numeric(main_df['postcode'])
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast)
#     133             coerce_numeric = False if errors in ('ignore', 'raise') else True
#     134             values = lib.maybe_convert_numeric(values, set(),
# --> 135                                                coerce_numeric=coerce_numeric)
#     136
#     137     except Exception:
#
# ...

# %%
main_df = pd.read_csv("final_file.csv")

# %%
main_df.shape
# Out:
# (9720, 9)

# %%
main_df = main_df.dropna(axis = 0)

# %%
main_df.columns
# Out:
# Index(['longitude', 'latitude', 'name', 'council', 'postcode', 'address',
#        'category'],
#       dtype='object')

# %%
del main_df['index']

# %%
main_df['postcode'] = pd.to_numeric(main_df['postcode'])

# %%
type(main_df['postcode'][1])
# Out:
# numpy.float64

# %%
import numpy
main_df['postcode'] = main_df['postcode'].astype(numpy.int64)

# %%
main_df.to_csv('final_file_poi.csv')
